# %%
# -*- coding: utf-8 -*-

import os
import csv
import numpy as np
import subprocess
import librosa

# %%
dirpath = "../data/LearningData/magiarecord/"
csvpath = "../data/LearningData/magiarecord/csvdata/main_5-7.csv"
wavpath = "../data/LearningData/magiarecord/main/main_5-7.wav"

# %%
def loadDivideLine(filepath):
    #音声の区切り位置読み込み
    #input [min.、sec.、人物ID]
    #output1 [sec., ...]
    #output2 [id1, ...]
    if not os.path.exists(filepath):
        print('divide_time data is nothing')
        print('o・∇・o')
    
    divideline = []
    with open(filepath, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            divideline.append(row)
    divideline = np.array(divideline,dtype='float64')
    
    divide_sec = 60*divideline.T[0]+divideline.T[1]
    peoplelist = np.array(divideline.T[2],dtype='int32')
    
    diff = divide_sec[1:]-divide_sec[:-1]

    if min(diff) < 0:
        print('divide_time value is wrong')
        print('o・∇・o')
        return -1,-1
    
    return divide_sec,peoplelist

#divide_sec,peoplelist = loadDivideLine(csvpath)

# %%
def countWavefile(dirpath,peoplelist):
    #既にあるwavファイル数をカウントする
    #ディレクトリなければmkdir
    number_of_data = {}
    directory_path = {}
    for people in set(peoplelist):
        people = int(people)
        if people == 0:
            continue
        if not os.path.exists(dirpath+str(people)):
            subprocess.call('mkdir '+dirpath+str(people))
        number_of_data[people] = len(os.listdir(dirpath+str(people)))
        directory_path[people] = dirpath+str(people)+'/'
            
    return number_of_data,directory_path

#countWavefile(dirpath,peoplelist)

# %%
def loadWavefile(filename,rate=44100,mono=True):
    #wavファイル読み込み
    if not os.path.exists(filename):
        print('wav data is nothing')
        print('o・∇・o')
    y,sr = librosa.load(filename,sr=rate,mono=mono)
    return y,sr

def outputWavefile(filepath,y,rate=44100):
    #wavファイル出力
    if os.path.exists(filepath):
        print('wav data is already there')
        print('o・∇・o')
    librosa.output.write_wav(filepath,y,rate)

# %%
def divideWavefile(csvpath,wavpath,dirpath):
    
    #分割時刻データ読み込み
    divide_sec,peoplelist = loadDivideLine(csvpath)
    
    
    #Wavファイル数カウント
    #なければmkdir
    number_of_data,directory_path = countWavefile(dirpath,peoplelist)
        
    #wav data読み込み
    print('Loading wav data')
    wave, fs = loadWavefile(wavpath)
    
    #wav data分割
    last_time = 0.0
    for time,people in zip(divide_sec,peoplelist):
        
        if people == 0:
            last_time = time
            continue
            
        s = int(last_time * fs)
        e = int(time * fs)
        split_data_path = directory_path[people]+str(number_of_data[people])+'.wav'
        print(last_time,people,split_data_path)
        wave_part = wave[s:e]
        outputWavefile(split_data_path,wave_part)
            
        number_of_data[people] += 1
        last_time = time

# %%
#divideWavefile(csvpath,wavpath,dirpath)
# Out:
# Loading wav data
# 9.0 12 ../data/LearningData/magiarecord/12/297.wav
# 17.45 1 ../data/LearningData/magiarecord/1/1626.wav
# 20.878 13 ../data/LearningData/magiarecord/13/136.wav
# 25.588 1 ../data/LearningData/magiarecord/1/1627.wav
# 30.603 12 ../data/LearningData/magiarecord/12/298.wav
# 36.139 11 ../data/LearningData/magiarecord/11/122.wav
# 38.771 12 ../data/LearningData/magiarecord/12/299.wav
# 42.274 11 ../data/LearningData/magiarecord/11/123.wav
# 47.687 4 ../data/LearningData/magiarecord/4/400.wav
# 53.162 3 ../data/LearningData/magiarecord/3/382.wav
# 57.177 2 ../data/LearningData/magiarecord/2/890.wav
# 60.442 1 ../data/LearningData/magiarecord/1/1628.wav
# 63.103 11 ../data/LearningData/magiarecord/11/124.wav
# 67.131 11 ../data/LearningData/magiarecord/11/125.wav
# 76.5 13 ../data/LearningData/magiarecord/13/137.wav
# 80.0 12 ../data/LearningData/magiarecord/12/300.wav
# 84.26 1 ../data/LearningData/magiarecord/1/1629.wav
# 96.351 1 ../data/LearningData/magiarecord/1/1630.wav
# 98.685 1 ../data/LearningData/magiarecord/1/1631.wav
# 108.682 1 ../data/LearningData/magiarecord/1/1632.wav
# 111.783 5 ../data/LearningData/magiarecord/5/101.wav
# 119.478 5 ../data/LearningData/magiarecord/5/102.wav
# 126.788 5 ../data/LearningData/magiarecord/5/103.wav
# 133.515 1 ../data/LearningData/magiarecord/1/1633.wav
# 139.05 2 ../data/LearningData/magiarecord/2/891.wav
# 144.51 5 ../data/LearningData/magiarecord/5/104.wav
# 158.852 1 ../data/LearningData/magiarecord/1/1634.wav
# 179.723 1 ../data/LearningData/magiarecord/1/1635.wav
# 182.636 5 ../data/LearningData/magiarecord/5/105.wav
# 189.043 1 ../data/LearningData/magiarecord/1/1636.wav
# 193.981 4 ../data/LearningData/magiarecord/4/401.wav
# 200.115 1 ../data/LearningData/magiarecord/1/1637.wav
# 213.093 2 ../data/LearningData/magiarecord/2/892.wav
# 218.704 1 ../data/LearningData/magiarecord/1/1638.wav
# 221.25 2 ../data/LearningData/magiarecord/2/893.wav
# 225.179 5 ../data/LearningData/magiarecord/5/106.wav
# 230.873 1 ../data/LearningData/magiarecord/1/1639.wav
# 237.359 1 ../data/LearningData/magiarecord/1/1640.wav
# 257.777 5 ../data/LearningData/magiarecord/5/107.wav
# 259.583 2 ../data/LearningData/magiarecord/2/894.wav
# 264.738 5 ../data/LearningData/magiarecord/5/108.wav
# 267.139 3 ../data/LearningData/magiarecord/3/383.wav
# 270.225 2 ../data/LearningData/magiarecord/2/895.wav
# 274.654 3 ../data/LearningData/magiarecord/3/384.wav
# 278.074 2 ../data/LearningData/magiarecord/2/896.wav
# 280.575 4 ../data/LearningData/magiarecord/4/402.wav
# 284.394 1 ../data/LearningData/magiarecord/1/1641.wav
# 286.366 3 ../data/LearningData/magiarecord/3/385.wav
# 288.629 5 ../data/LearningData/magiarecord/5/109.wav
# 292.328 2 ../data/LearningData/magiarecord/2/897.wav
# 296.845 3 ../data/LearningData/magiarecord/3/386.wav
# 299.334 5 ../data/LearningData/magiarecord/5/110.wav
# 306.597 2 ../data/LearningData/magiarecord/2/898.wav
# 316.161 5 ../data/LearningData/magiarecord/5/111.wav
# 318.354 3 ../data/LearningData/magiarecord/3/387.wav
# 320.505 5 ../data/LearningData/magiarecord/5/112.wav
# 333.932 1 ../data/LearningData/magiarecord/1/1642.wav
# 346.363 2 ../data/LearningData/magiarecord/2/899.wav
# 351.044 4 ../data/LearningData/magiarecord/4/403.wav
# 354.626 2 ../data/LearningData/magiarecord/2/900.wav
# 356.602 4 ../data/LearningData/magiarecord/4/404.wav
# 358.669 2 ../data/LearningData/magiarecord/2/901.wav
# 360.59 5 ../data/LearningData/magiarecord/5/113.wav
# 364.093 4 ../data/LearningData/magiarecord/4/405.wav
# 368.894 5 ../data/LearningData/magiarecord/5/114.wav
# 374.519 4 ../data/LearningData/magiarecord/4/406.wav
# 376.575 5 ../data/LearningData/magiarecord/5/115.wav
# 382.766 3 ../data/LearningData/magiarecord/3/388.wav
# 390.96 5 ../data/LearningData/magiarecord/5/116.wav
# 393.934 3 ../data/LearningData/magiarecord/3/389.wav
# 397.175 4 ../data/LearningData/magiarecord/4/407.wav
# 404.759 5 ../data/LearningData/magiarecord/5/117.wav
# 410.063 1 ../data/LearningData/magiarecord/1/1643.wav
# 414.413 1 ../data/LearningData/magiarecord/1/1644.wav
# 417.217 5 ../data/LearningData/magiarecord/5/118.wav
# 424.185 1 ../data/LearningData/magiarecord/1/1645.wav
# 430.0 5 ../data/LearningData/magiarecord/5/119.wav
# 434.287 1 ../data/LearningData/magiarecord/1/1646.wav
# 439.083 5 ../data/LearningData/magiarecord/5/120.wav
# 446.553 1 ../data/LearningData/magiarecord/1/1647.wav
# 449.062 5 ../data/LearningData/magiarecord/5/121.wav
# 455.0 1 ../data/LearningData/magiarecord/1/1648.wav
# 467.0 1 ../data/LearningData/magiarecord/1/1649.wav
# 484.868 5 ../data/LearningData/magiarecord/5/122.wav
# 492.58 1 ../data/LearningData/magiarecord/1/1650.wav
# 498.454 5 ../data/LearningData/magiarecord/5/123.wav
# 504.045 1 ../data/LearningData/magiarecord/1/1651.wav
# 506.091 1 ../data/LearningData/magiarecord/1/1652.wav
# 508.802 5 ../data/LearningData/magiarecord/5/124.wav
# 512.75 2 ../data/LearningData/magiarecord/2/902.wav
# 515.191 5 ../data/LearningData/magiarecord/5/125.wav
# 517.515 1 ../data/LearningData/magiarecord/1/1653.wav
# 520.157 1 ../data/LearningData/magiarecord/1/1654.wav
# 525.171 5 ../data/LearningData/magiarecord/5/126.wav
# 533.62 1 ../data/LearningData/magiarecord/1/1655.wav
# 544.299 5 ../data/LearningData/magiarecord/5/127.wav
# 556.765 5 ../data/LearningData/magiarecord/5/128.wav
# 558.638 55 ../data/LearningData/magiarecord/55/0.wav
# 560.647 54 ../data/LearningData/magiarecord/54/0.wav
# 562.691 5 ../data/LearningData/magiarecord/5/129.wav
# 565.556 54 ../data/LearningData/magiarecord/54/1.wav
# 571.873 56 ../data/LearningData/magiarecord/56/0.wav
# 575.542 55 ../data/LearningData/magiarecord/55/1.wav
# 580.825 56 ../data/LearningData/magiarecord/56/1.wav
# 587.306 5 ../data/LearningData/magiarecord/5/130.wav
# 590.074 55 ../data/LearningData/magiarecord/55/2.wav
# 593.275 57 ../data/LearningData/magiarecord/57/0.wav
# 601.163 54 ../data/LearningData/magiarecord/54/2.wav
# 611.0 57 ../data/LearningData/magiarecord/57/1.wav
# 617.717 5 ../data/LearningData/magiarecord/5/131.wav
# 638.417 55 ../data/LearningData/magiarecord/55/3.wav
# 643.967 54 ../data/LearningData/magiarecord/54/3.wav
# 647.047 55 ../data/LearningData/magiarecord/55/4.wav
# 649.836 54 ../data/LearningData/magiarecord/54/4.wav
# 651.993 55 ../data/LearningData/magiarecord/55/5.wav
# 655.824 57 ../data/LearningData/magiarecord/57/2.wav
# 658.458 56 ../data/LearningData/magiarecord/56/2.wav
# 661.582 5 ../data/LearningData/magiarecord/5/132.wav
# 663.647 5 ../data/LearningData/magiarecord/5/133.wav
# 672.145 5 ../data/LearningData/magiarecord/5/134.wav
# 713.592 5 ../data/LearningData/magiarecord/5/135.wav
# 723.682 5 ../data/LearningData/magiarecord/5/136.wav
# 732.428 5 ../data/LearningData/magiarecord/5/137.wav
# 745.949 1 ../data/LearningData/magiarecord/1/1656.wav
# 755.357 12 ../data/LearningData/magiarecord/12/301.wav
# 760.199 11 ../data/LearningData/magiarecord/11/126.wav
# 766.65 13 ../data/LearningData/magiarecord/13/138.wav
# 774.0 11 ../data/LearningData/magiarecord/11/127.wav
# 780.482 13 ../data/LearningData/magiarecord/13/139.wav
# 787.432 11 ../data/LearningData/magiarecord/11/128.wav
# 791.0 13 ../data/LearningData/magiarecord/13/140.wav
# 808.117 11 ../data/LearningData/magiarecord/11/129.wav
# 810.145 12 ../data/LearningData/magiarecord/12/302.wav
# 813.0 13 ../data/LearningData/magiarecord/13/141.wav
# 816.903 12 ../data/LearningData/magiarecord/12/303.wav
# 820.66 1 ../data/LearningData/magiarecord/1/1657.wav
# 828.726 12 ../data/LearningData/magiarecord/12/304.wav
# 831.75 1 ../data/LearningData/magiarecord/1/1658.wav
# 833.747 1 ../data/LearningData/magiarecord/1/1659.wav
# 838.921 12 ../data/LearningData/magiarecord/12/305.wav
# 848.0 13 ../data/LearningData/magiarecord/13/142.wav
# 850.0 12 ../data/LearningData/magiarecord/12/306.wav
# 866.372 11 ../data/LearningData/magiarecord/11/130.wav
# 869.46 13 ../data/LearningData/magiarecord/13/143.wav
# 876.657 12 ../data/LearningData/magiarecord/12/307.wav
# 881.001 11 ../data/LearningData/magiarecord/11/131.wav
# 882.26 12 ../data/LearningData/magiarecord/12/308.wav
# 889.0 11 ../data/LearningData/magiarecord/11/132.wav
# 892.672 13 ../data/LearningData/magiarecord/13/144.wav
# 903.846 2 ../data/LearningData/magiarecord/2/903.wav
# 906.69 3 ../data/LearningData/magiarecord/3/390.wav
# 909.149 5 ../data/LearningData/magiarecord/5/138.wav
# 910.953 2 ../data/LearningData/magiarecord/2/904.wav
# 916.036 4 ../data/LearningData/magiarecord/4/408.wav
# 918.368 1 ../data/LearningData/magiarecord/1/1660.wav
# 921.0 2 ../data/LearningData/magiarecord/2/905.wav
# 925.446 3 ../data/LearningData/magiarecord/3/391.wav
# 928.511 2 ../data/LearningData/magiarecord/2/906.wav
# 930.818 1 ../data/LearningData/magiarecord/1/1661.wav
# 933.054 2 ../data/LearningData/magiarecord/2/907.wav
# 940.044 5 ../data/LearningData/magiarecord/5/139.wav
# 942.57 1 ../data/LearningData/magiarecord/1/1662.wav
# 944.916 5 ../data/LearningData/magiarecord/5/140.wav
# 951.55 5 ../data/LearningData/magiarecord/5/141.wav
# 955.42 5 ../data/LearningData/magiarecord/5/142.wav
# 960.553 2 ../data/LearningData/magiarecord/2/908.wav
# 964.463 3 ../data/LearningData/magiarecord/3/392.wav
# 968.448 4 ../data/LearningData/magiarecord/4/409.wav
# 971.982 1 ../data/LearningData/magiarecord/1/1663.wav
# 980.933 5 ../data/LearningData/magiarecord/5/143.wav
# 990.539 1 ../data/LearningData/magiarecord/1/1664.wav
# 1000.222 5 ../data/LearningData/magiarecord/5/144.wav
# 1003.243 1 ../data/LearningData/magiarecord/1/1665.wav
# 1006.0 5 ../data/LearningData/magiarecord/5/145.wav
# 1008.32 1 ../data/LearningData/magiarecord/1/1666.wav
# 1013.026 5 ../data/LearningData/magiarecord/5/146.wav
# 1018.02 1 ../data/LearningData/magiarecord/1/1667.wav
# 1020.291 5 ../data/LearningData/magiarecord/5/147.wav
# 1022.62 1 ../data/LearningData/magiarecord/1/1668.wav
# 1025.628 5 ../data/LearningData/magiarecord/5/148.wav
# 1029.211 1 ../data/LearningData/magiarecord/1/1669.wav
# 1035.512 5 ../data/LearningData/magiarecord/5/149.wav
# 1049.991 2 ../data/LearningData/magiarecord/2/909.wav
# 1052.964 1 ../data/LearningData/magiarecord/1/1670.wav
# 1060.451 5 ../data/LearningData/magiarecord/5/150.wav
# 1065.368 1 ../data/LearningData/magiarecord/1/1671.wav
# 1071.996 5 ../data/LearningData/magiarecord/5/151.wav
# 1073.936 3 ../data/LearningData/magiarecord/3/393.wav
# 1081.412 5 ../data/LearningData/magiarecord/5/152.wav
# 1091.944 3 ../data/LearningData/magiarecord/3/394.wav
# 1093.651 5 ../data/LearningData/magiarecord/5/153.wav
# 1115.595 1 ../data/LearningData/magiarecord/1/1672.wav
# 1117.933 2 ../data/LearningData/magiarecord/2/910.wav
# 1119.971 2 ../data/LearningData/magiarecord/2/911.wav
# 1130.235 1 ../data/LearningData/magiarecord/1/1673.wav
# 1139.354 1 ../data/LearningData/magiarecord/1/1674.wav
# 1144.187 5 ../data/LearningData/magiarecord/5/154.wav
# 1158.53 1 ../data/LearningData/magiarecord/1/1675.wav
# 1169.7 1 ../data/LearningData/magiarecord/1/1676.wav
# 1206.682 1 ../data/LearningData/magiarecord/1/1677.wav

# %%
#それぞれのキャラのデータサイズ確認

path = "../data/LearningData/magiarecord/"
charcsvpath = "../data/LearningData/magiarecord/csvdata/character_import.csv"

char = {}
with open(charcsvpath,'r')as f:
    data = csv.reader(f)
    for low in data:
        char[int(low[0])] = str(low[1])
        

allsize = 0
sizedata = []
for a in range(1,51):
    sizesum = 0
    filepath = path + str(a)
    if not os.path.exists(filepath):
        continue
    filelist = os.listdir(path+str(a)+'/')
    for f in filelist:
        size = os.path.getsize(filepath+'/'+f)
        sizesum += size
    #if sizesum < 1000:
    #    continue
    sizesum = sizesum / 1024 / 1024
    print(a,char[a],round(sizesum,3),'MB')
    allsize += sizesum
print('\nall',round(allsize/1024,3),'GB')
# Out:
# 1 環いろは 1590.763 MB
# 2 七海やちよ 882.288 MB
# 3 由比鶴乃 388.09 MB
# 4 深月フェリシア 355.503 MB
# 5 二葉さな 232.382 MB
# 6 ウワサの鶴乃 52.41 MB
# 11 秋野かえで 169.762 MB
# 12 十咎ももこ 333.866 MB
# 13 水波レナ 231.02 MB
# 14 八雲みたま 137.971 MB
# 15 雪野かなえ 53.688 MB
# 16 安名メル 47.195 MB
# 17 和泉十七夜（仮置） 0.0 MB
# 21 鹿目まどか（振袖含） 188.977 MB
# 22 暁美ほむら 180.973 MB
# 23 巴マミ（突然失礼含） 84.547 MB
# 24 佐倉杏子 197.568 MB
# 25 美樹さやか 0.0 MB
# 31 環うい 22.74 MB
# 32 里見灯火 22.238 MB
# 33 柊ねむ 17.538 MB
# 34 アリナグレイ 95.435 MB
# 35 梓みふゆ 58.925 MB
# 36 天音月咲 80.222 MB
# 37 天音月夜 131.232 MB
# 38 黒羽根（ミザリー） 22.405 MB
# 39 黒羽根（アイ） 1.307 MB
# 41 もきゅ 13.642 MB
# 42 キュゥべえ 4.593 MB
# 43 ウワサ 27.736 MB
# 44 給水おじさん 6.362 MB
# 45 アイ 53.289 MB
#
# all 5.551 GB
