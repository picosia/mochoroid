# %%
# -*- coding: utf-8 -*-

import os
import csv
import numpy as np
import subprocess
import librosa

# %%
dirpath = "../data/LearningData/magiarecord/"
csvpath = "../data/LearningData/magiarecord/csvdata/main_1-3.csv"
wavpath = "../data/LearningData/magiarecord/main/main_1-3.wav"

# %%
def loadDivideLine(filepath):
    #音声の区切り位置読み込み
    #input [min.、sec.、人物ID]
    #output1 [sec., ...]
    #output2 [id1, ...]
    if not os.path.exists(filepath):
        print('divide_time data is nothing')
        print('o・∇・o')
    
    divideline = []
    with open(filepath, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            divideline.append(row)
    divideline = np.array(divideline,dtype='float64')
    
    divide_sec = 60*divideline.T[0]+divideline.T[1]
    peoplelist = np.array(divideline.T[2],dtype='int32')
    
    diff = divide_sec[1:]-divide_sec[:-1]
    if min(diff) < 0:
        print('divide_time value is wrong')
        print('o・∇・o')
    
    return divide_sec,peoplelist

#divide_sec,peoplelist = loadDivideLine(csvpath)

# %%
def countWavefile(dirpath,peoplelist):
    #既にあるwavファイル数をカウントする
    #ディレクトリなければmkdir
    number_of_data = {}
    directory_path = {}
    for people in set(peoplelist):
        people = int(people)
        if people == 0:
            continue
        if not os.path.exists(dirpath+str(people)):
            subprocess.call('mkdir '+dirpath+str(people))
        number_of_data[people] = len(os.listdir(dirpath+str(people)))
        directory_path[people] = dirpath+str(people)+'/'
            
    return number_of_data,directory_path

#countWavefile(dirpath,peoplelist)

# %%
def loadWavefile(filename,rate=44100,mono=True):
    #wavファイル読み込み
    if not os.path.exists(filename):
        print('wav data is nothing')
        print('o・∇・o')
    y,sr = librosa.load(filename,sr=rate,mono=mono)
    return y,sr

def outputWavefile(filepath,y,rate=44100):
    #wavファイル出力
    if os.path.exists(filepath):
        print('wav data is already there')
        print('o・∇・o')
    librosa.output.write_wav(filepath,y,rate)

# %%
def divideWavefile(csvpath,wavpath,dirpath):
    
    #分割時刻データ読み込み
    divide_sec,peoplelist = loadDivideLine(csvpath)
    
    #Wavファイル数カウント
    #なければmkdir
    number_of_data,directory_path = countWavefile(dirpath,peoplelist)
        
    #wav data読み込み
    print('Loading wav data')
    wave, fs = loadWavefile(wavpath)
    
    #wav data分割
    last_time = 0.0
    for time,people in zip(divide_sec,peoplelist):
        
        if people == 0:
            last_time = time
            continue
            
        s = int(last_time * fs)
        e = int(time * fs)
        split_data_path = directory_path[people]+str(number_of_data[people])+'.wav'
        print(last_time,people,split_data_path)
        wave_part = wave[s:e]
        outputWavefile(split_data_path,wave_part)
            
        number_of_data[people] += 1
        last_time = time

# %%
#divideWavefile(csvpath,wavpath,dirpath)
# Out:
# Loading wav data
# 4.0 1 ../data/LearningData/magiarecord/1/101.wav
# 6.5 12 ../data/LearningData/magiarecord/12/39.wav
# 9.0 2 ../data/LearningData/magiarecord/2/26.wav
# 18.0 1 ../data/LearningData/magiarecord/1/102.wav
# 19.5 2 ../data/LearningData/magiarecord/2/27.wav
# 30.5 1 ../data/LearningData/magiarecord/1/103.wav
# 32.0 12 ../data/LearningData/magiarecord/12/40.wav
# 39.1 2 ../data/LearningData/magiarecord/2/28.wav
# 47.0 1 ../data/LearningData/magiarecord/1/104.wav
# 64.0 2 ../data/LearningData/magiarecord/2/29.wav
# 66.7 12 ../data/LearningData/magiarecord/12/41.wav
# 74.8 12 ../data/LearningData/magiarecord/12/42.wav
# 78.7 1 ../data/LearningData/magiarecord/1/105.wav
# 82.0 12 ../data/LearningData/magiarecord/12/43.wav
# 93.8 2 ../data/LearningData/magiarecord/2/30.wav
# 96.0 12 ../data/LearningData/magiarecord/12/44.wav
# 101.4 1 ../data/LearningData/magiarecord/1/106.wav
# 104.6 12 ../data/LearningData/magiarecord/12/45.wav
# 109.0 1 ../data/LearningData/magiarecord/1/107.wav
# 110.8 12 ../data/LearningData/magiarecord/12/46.wav
# 114.0 41 ../data/LearningData/magiarecord/41/2.wav
# 116.9 1 ../data/LearningData/magiarecord/1/108.wav
# 120.0 12 ../data/LearningData/magiarecord/12/47.wav
# 123.9 1 ../data/LearningData/magiarecord/1/109.wav
# 131.4 12 ../data/LearningData/magiarecord/12/48.wav
# 143.1 1 ../data/LearningData/magiarecord/1/110.wav
# 146.0 12 ../data/LearningData/magiarecord/12/49.wav
# 154.0 1 ../data/LearningData/magiarecord/1/111.wav
# 156.0 41 ../data/LearningData/magiarecord/41/3.wav
# 158.0 1 ../data/LearningData/magiarecord/1/112.wav
# 159.9 41 ../data/LearningData/magiarecord/41/4.wav
# 162.4 12 ../data/LearningData/magiarecord/12/50.wav
# 165.6 1 ../data/LearningData/magiarecord/1/113.wav
# 167.9 41 ../data/LearningData/magiarecord/41/5.wav
# 169.2 1 ../data/LearningData/magiarecord/1/114.wav
# 173.3 41 ../data/LearningData/magiarecord/41/6.wav
# 175.1 12 ../data/LearningData/magiarecord/12/51.wav
# 182.0 1 ../data/LearningData/magiarecord/1/115.wav
# 183.8 41 ../data/LearningData/magiarecord/41/7.wav
# 185.0 1 ../data/LearningData/magiarecord/1/116.wav
# 190.5 12 ../data/LearningData/magiarecord/12/52.wav
# 195.2 1 ../data/LearningData/magiarecord/1/117.wav
# 200.5 12 ../data/LearningData/magiarecord/12/53.wav
# 209.0 1 ../data/LearningData/magiarecord/1/118.wav
# 216.0 12 ../data/LearningData/magiarecord/12/54.wav
# 219.2 1 ../data/LearningData/magiarecord/1/119.wav
# 221.0 12 ../data/LearningData/magiarecord/12/55.wav
# 223.8 1 ../data/LearningData/magiarecord/1/120.wav
# 229.2 12 ../data/LearningData/magiarecord/12/56.wav
# 233.4 1 ../data/LearningData/magiarecord/1/121.wav
# 240.5 41 ../data/LearningData/magiarecord/41/8.wav
# 243.0 1 ../data/LearningData/magiarecord/1/122.wav
# 246.2 12 ../data/LearningData/magiarecord/12/57.wav
# 255.8 1 ../data/LearningData/magiarecord/1/123.wav
# 259.2 12 ../data/LearningData/magiarecord/12/58.wav
# 262.8 1 ../data/LearningData/magiarecord/1/124.wav
# 269.0 12 ../data/LearningData/magiarecord/12/59.wav
# 273.0 1 ../data/LearningData/magiarecord/1/125.wav
# 284.5 2 ../data/LearningData/magiarecord/2/31.wav
# 287.0 1 ../data/LearningData/magiarecord/1/126.wav
# 293.0 1 ../data/LearningData/magiarecord/1/127.wav
# 297.0 2 ../data/LearningData/magiarecord/2/32.wav
# 300.0 12 ../data/LearningData/magiarecord/12/60.wav
# 305.5 2 ../data/LearningData/magiarecord/2/33.wav
# 314.4 12 ../data/LearningData/magiarecord/12/61.wav
# 316.0 2 ../data/LearningData/magiarecord/2/34.wav
# 320.5 1 ../data/LearningData/magiarecord/1/128.wav
# 322.2 2 ../data/LearningData/magiarecord/2/35.wav
# 326.0 1 ../data/LearningData/magiarecord/1/129.wav
# 328.6 2 ../data/LearningData/magiarecord/2/36.wav
# 339.6 1 ../data/LearningData/magiarecord/1/130.wav
# 341.5 12 ../data/LearningData/magiarecord/12/62.wav
# 345.6 2 ../data/LearningData/magiarecord/2/37.wav
# 356.7 12 ../data/LearningData/magiarecord/12/63.wav
# 358.0 2 ../data/LearningData/magiarecord/2/38.wav
# 361.0 1 ../data/LearningData/magiarecord/1/131.wav
# 373.4 2 ../data/LearningData/magiarecord/2/39.wav
# 380.0 12 ../data/LearningData/magiarecord/12/64.wav
# 382.0 1 ../data/LearningData/magiarecord/1/132.wav
# 384.2 2 ../data/LearningData/magiarecord/2/40.wav
# 394.0 1 ../data/LearningData/magiarecord/1/133.wav
# 398.2 12 ../data/LearningData/magiarecord/12/65.wav
# 400.9 41 ../data/LearningData/magiarecord/41/9.wav
# 410.4 12 ../data/LearningData/magiarecord/12/66.wav
# 412.4 1 ../data/LearningData/magiarecord/1/134.wav
# 416.4 12 ../data/LearningData/magiarecord/12/67.wav
# 418.5 2 ../data/LearningData/magiarecord/2/41.wav
# 424.0 12 ../data/LearningData/magiarecord/12/68.wav
# 428.0 2 ../data/LearningData/magiarecord/2/42.wav
# 435.0 1 ../data/LearningData/magiarecord/1/135.wav
# 438.0 2 ../data/LearningData/magiarecord/2/43.wav
# 443.2 1 ../data/LearningData/magiarecord/1/136.wav
# 447.5 12 ../data/LearningData/magiarecord/12/69.wav
# 450.8 2 ../data/LearningData/magiarecord/2/44.wav
# 457.2 1 ../data/LearningData/magiarecord/1/137.wav
# 459.0 2 ../data/LearningData/magiarecord/2/45.wav
# 468.2 1 ../data/LearningData/magiarecord/1/138.wav
# 470.5 2 ../data/LearningData/magiarecord/2/46.wav
# 487.0 1 ../data/LearningData/magiarecord/1/139.wav
# 490.0 12 ../data/LearningData/magiarecord/12/70.wav
# 492.1 2 ../data/LearningData/magiarecord/2/47.wav
# 494.1 12 ../data/LearningData/magiarecord/12/71.wav
# 496.5 41 ../data/LearningData/magiarecord/41/10.wav
# 498.5 1 ../data/LearningData/magiarecord/1/140.wav
# 501.0 2 ../data/LearningData/magiarecord/2/48.wav
# 504.0 1 ../data/LearningData/magiarecord/1/141.wav
# 512.0 2 ../data/LearningData/magiarecord/2/49.wav
# 517.9 1 ../data/LearningData/magiarecord/1/142.wav
# 520.8 2 ../data/LearningData/magiarecord/2/50.wav
# 525.6 1 ../data/LearningData/magiarecord/1/143.wav
# 543.5 2 ../data/LearningData/magiarecord/2/51.wav
# 549.5 1 ../data/LearningData/magiarecord/1/144.wav
# 551.0 41 ../data/LearningData/magiarecord/41/11.wav
# 553.0 2 ../data/LearningData/magiarecord/2/52.wav
# 558.1 1 ../data/LearningData/magiarecord/1/145.wav
# 564.5 1 ../data/LearningData/magiarecord/1/146.wav
# 569.0 12 ../data/LearningData/magiarecord/12/72.wav
# 571.0 2 ../data/LearningData/magiarecord/2/53.wav
# 579.5 1 ../data/LearningData/magiarecord/1/147.wav
# 582.0 1 ../data/LearningData/magiarecord/1/148.wav
# 584.0 1 ../data/LearningData/magiarecord/1/149.wav
# 592.2 31 ../data/LearningData/magiarecord/31/5.wav
# 597.4 1 ../data/LearningData/magiarecord/1/150.wav
# 601.5 31 ../data/LearningData/magiarecord/31/6.wav
# 609.6 1 ../data/LearningData/magiarecord/1/151.wav
# 617.9 31 ../data/LearningData/magiarecord/31/7.wav
# 624.5 1 ../data/LearningData/magiarecord/1/152.wav
# 631.5 1 ../data/LearningData/magiarecord/1/153.wav
# 657.0 31 ../data/LearningData/magiarecord/31/8.wav
# 662.7 1 ../data/LearningData/magiarecord/1/154.wav
# 666.8 1 ../data/LearningData/magiarecord/1/155.wav
# 706.7 42 ../data/LearningData/magiarecord/42/3.wav
# 716.0 1 ../data/LearningData/magiarecord/1/156.wav
# 718.3 14 ../data/LearningData/magiarecord/14/25.wav
# 724.5 12 ../data/LearningData/magiarecord/12/73.wav
# 728.5 1 ../data/LearningData/magiarecord/1/157.wav
# 732.0 12 ../data/LearningData/magiarecord/12/74.wav
# 735.6 1 ../data/LearningData/magiarecord/1/158.wav
# 743.2 12 ../data/LearningData/magiarecord/12/75.wav
# 745.0 1 ../data/LearningData/magiarecord/1/159.wav
# 758.2 12 ../data/LearningData/magiarecord/12/76.wav
# 766.4 1 ../data/LearningData/magiarecord/1/160.wav
# 784.2 12 ../data/LearningData/magiarecord/12/77.wav
# 786.5 1 ../data/LearningData/magiarecord/1/161.wav
# 804.6 14 ../data/LearningData/magiarecord/14/26.wav
# 812.0 1 ../data/LearningData/magiarecord/1/162.wav
# 814.8 14 ../data/LearningData/magiarecord/14/27.wav
# 817.5 12 ../data/LearningData/magiarecord/12/78.wav
# 822.5 14 ../data/LearningData/magiarecord/14/28.wav
# 825.5 1 ../data/LearningData/magiarecord/1/163.wav
# 830.5 41 ../data/LearningData/magiarecord/41/12.wav
# 832.2 1 ../data/LearningData/magiarecord/1/164.wav
# 846.0 41 ../data/LearningData/magiarecord/41/13.wav
# 847.5 1 ../data/LearningData/magiarecord/1/165.wav
# 856.8 12 ../data/LearningData/magiarecord/12/79.wav
# 858.5 1 ../data/LearningData/magiarecord/1/166.wav
# 863.5 12 ../data/LearningData/magiarecord/12/80.wav
# 866.0 1 ../data/LearningData/magiarecord/1/167.wav
# 888.5 14 ../data/LearningData/magiarecord/14/29.wav
# 899.2 1 ../data/LearningData/magiarecord/1/168.wav
# 906.0 1 ../data/LearningData/magiarecord/1/169.wav
# 921.8 1 ../data/LearningData/magiarecord/1/170.wav
# 1024.4 12 ../data/LearningData/magiarecord/12/81.wav
# 1033.4 1 ../data/LearningData/magiarecord/1/171.wav
# 1035.0 12 ../data/LearningData/magiarecord/12/82.wav
# 1044.2 14 ../data/LearningData/magiarecord/14/30.wav
# 1049.1 12 ../data/LearningData/magiarecord/12/83.wav
# 1051.2 14 ../data/LearningData/magiarecord/14/31.wav
# 1053.0 12 ../data/LearningData/magiarecord/12/84.wav
# 1061.8 1 ../data/LearningData/magiarecord/1/172.wav
# 1064.8 14 ../data/LearningData/magiarecord/14/32.wav
# 1067.5 1 ../data/LearningData/magiarecord/1/173.wav
# 1069.0 14 ../data/LearningData/magiarecord/14/33.wav
# 1073.0 1 ../data/LearningData/magiarecord/1/174.wav
# 1074.5 14 ../data/LearningData/magiarecord/14/34.wav
# 1084.5 1 ../data/LearningData/magiarecord/1/175.wav
# 1088.4 14 ../data/LearningData/magiarecord/14/35.wav
# 1094.7 1 ../data/LearningData/magiarecord/1/176.wav
# 1100.2 14 ../data/LearningData/magiarecord/14/36.wav
# 1104.5 1 ../data/LearningData/magiarecord/1/177.wav
# 1110.9 1 ../data/LearningData/magiarecord/1/178.wav
# 1113.0 14 ../data/LearningData/magiarecord/14/37.wav
# 1116.3 41 ../data/LearningData/magiarecord/41/14.wav
# 1118.3 12 ../data/LearningData/magiarecord/12/85.wav
# 1121.0 1 ../data/LearningData/magiarecord/1/179.wav
# 1125.4 1 ../data/LearningData/magiarecord/1/180.wav
# 1131.0 41 ../data/LearningData/magiarecord/41/15.wav
# 1133.0 1 ../data/LearningData/magiarecord/1/181.wav

# %%
#それぞれのキャラのデータサイズ確認

path = "../data/LearningData/magiarecord/"

allsize = 0
sizedata = []
for a in range(1,101):
    sizesum = 0
    filepath = path + str(a)
    if not os.path.exists(filepath):
        continue
    filelist = os.listdir(path+str(a)+'/')
    for f in filelist:
        size = os.path.getsize(filepath+'/'+f)
        sizesum += size
    if sizesum < 1000:
        continue
    sizesum = sizesum / 1024 / 1024
    if sizesum > 1024:
        print(a,round(sizesum/1024,3),'GB')
    else:
        print(a,round(sizesum,3),'MB')
    allsize += sizesum
print('\nall',round(allsize/1024,3),'GB')
# Out:
# 1 334.162 MB
# 2 150.041 MB
# 3 88.551 MB
# 4 84.414 MB
# 5 67.074 MB
# 11 80.439 MB
# 12 123.911 MB
# 13 87.449 MB
# 14 93.53 MB
# 21 123.116 MB
# 22 119.165 MB
# 23 67.46 MB
# 31 5.855 MB
# 36 44.137 MB
# 37 42.305 MB
# 41 4.661 MB
# 42 4.593 MB
#
# all 1.485 GB
